# %% [markdown]
# Hi Everyone,
#
# Running the code below will give you some 'relatively clean code to start the assignment.
# The output includes two files:
# - Processedspeeches, which is a list of lists with all the individual words.
# - df_speech, which is a pandas dataframe
#
# There are still some irregularities (such as points and commas pasting words together), and the data has not been tokenised yet.
# This is because every analysis might require different information and therefore requires its own specific cleaning process.
#
# I suggest we share our future cleaning steps so we can add them individually if needed.

# %%
import os
import numpy as np
import pandas as pd
import re

sessions = np.arange(25, 76)
data=[]

for session in sessions:
    directory = "./TXT/Session "+str(session)+" - "+str(1945+session)
    for filename in os.listdir(directory):
        f = open(os.path.join(directory, filename))
        if filename[0]==".": #ignore hidden files
            continue
        splt = filename.split("_")
        data.append([session, 1945+session, splt[0], f.read()])

# %%
# import warnings -> if you want to disable warnings
# warnings.filterwarnings("ignore")

# creating a data frame
df_speech = pd.DataFrame(data, columns=['Session','Year','ISO-alpha3 Code','Speech'])
df_speech['Speech'] = df_speech['Speech'].str.replace(r'\s+', ' ')
# Out:
# /var/folders/b9/5zvkvytn2ldcn51c9jnmb_yw0000gn/T/ipykernel_2456/3237648648.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_speech['Speech'] = df_speech['Speech'].str.replace(r'\s+', ' ')

# %%
# creating a clean list of list (wordbag)
processedspeeches = []
for j in df_speech.Speech:
    processedspeeches.append(j.split(' '))

for i in range(len(processedspeeches)):
    for j in range(len(processedspeeches[i])):
        processedspeeches[i][j] = re.sub('\s+', '', processedspeeches[i][j])

# %%
processedspeeches[:3]
# Out:
# [['155.',
#   'May',
#   'I',
#   'begin',
#   'by',
#   'expressing',
#   'to',
#   'Ambassador',
#   'Hambro,',
#   'on',
#   'behalf',
#   'of',
#   'the',
#   'delegation',
#   'of',
#   'Austria,',
#   'our',
#   'best',
#   'wishes',
#   'on',
#   'his',
#   'election',
#   'as',
#   'President',
#   'of',
#   'this',
#   'General',
#   'Assembly.',
#   '156.',
#   'We',
#   'derive',
#   'great',
#   'satisfaction',
#   'from',
#   'the',
#   'knowledge',
#   'that',
#   'this',
#   'twenty-fifth',
#   'session',
#   'of',
#   'the',
#   'United',
#   'Nations',
#   'will',
#   'be',
#   'held',
#   'under',
#   'the',
#   'Presidency',
#   'of',
#   'a',
#   'man',
#   'whom',
#   'we',
#   'not',
#   'only',
#   'admire',
#   'as',
#   'an',
#   'experienced',
#   'diplomat,',
#   'but',
#   'whose',
#   'background',
#   'and',
#   'personality',
#   'are',
#   'so',
#   'germane',
#   'to',
#   'the',
#   'problems',
#   'and',
#   'the',
#   'respect',
#   'of',
# ...
